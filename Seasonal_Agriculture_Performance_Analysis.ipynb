# %%
# VOIS AICTE Batch 2026-2027 | Major Project: Seasonal Agriculture Performance Analysis
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Configure visual styling
sns.set_theme(style="whitegrid")
# %matplotlib inline

# %%
# Objective: Explore and understand the dataset structure, features, and types
df = pd.read_csv('seasonal_agriculture_performance_dataset (1).csv')

print("--- 1. DATASET EXPLORATION ---")
print(f"Dataset Shape (Rows, Columns): {df.shape}")
print("\nColumn Data Types & Non-Null Counts:")
df.info()

print("\nFirst 5 Records:")
display(df.head())

print("\nSummary Statistics of Numerical Features:")
display(df.describe())
# Out:
# --- 1. DATASET EXPLORATION ---
# Dataset Shape (Rows, Columns): (4000, 28)
#
# Column Data Types & Non-Null Counts:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4000 entries, 0 to 3999
# Data columns (total 28 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Farm_ID                        4000 non-null   object
#  1   State                          4000 non-null   object
#  2   District                       4000 non-null   object
#  3   Crop                           4000 non-null   object
#  4   Season                         4000 non-null   object
#  5   Farm_Area_Hectares             4000 non-null   float64
#  6   Rainfall_mm                    3952 non-null   float64
#  7   Avg_Temperature_C              4000 non-null   float64
#  8   Humidity_pct                   4000 non-null   float64
#  9   Sunlight_Hours_Day             4000 non-null   float64
# ...

# %%
# Objective: Clean and prepare the data for analysis (Handling missing values)
print("--- 2. DATA CLEANING & PREPARATION ---")
print("Missing values before cleaning:\n", df.isnull().sum())

# Contextual Imputations:
# 1. Rainfall & Soil Moisture: Imputed using median grouped by State and Season
df['Rainfall_mm'] = df['Rainfall_mm'].fillna(df.groupby(['State', 'Season'])['Rainfall_mm'].transform('median'))
df['Soil_Moisture_pct'] = df['Soil_Moisture_pct'].fillna(df.groupby(['State', 'Season'])['Soil_Moisture_pct'].transform('median'))

# 2. Yield: Imputed using median grouped by Crop and Season
df['Yield_Tonnes_Ha'] = df['Yield_Tonnes_Ha'].fillna(df.groupby(['Crop', 'Season'])['Yield_Tonnes_Ha'].transform('median'))

print("\nMissing values after cleaning:\n", df.isnull().sum())
# Out:
# --- 2. DATA CLEANING & PREPARATION ---
# Missing values before cleaning:
#  Farm_ID                           0
# State                             0
# District                          0
# Crop                              0
# Season                            0
# Farm_Area_Hectares                0
# Rainfall_mm                      48
# Avg_Temperature_C                 0
# Humidity_pct                      0
# Sunlight_Hours_Day                0
# Soil_pH                           0
# Soil_Moisture_pct                40
# Nitrogen_kg_ha                    0
# Phosphorus_kg_ha                  0
# Potassium_kg_ha                   0
# Irrigation_Method                 0
# Fertilizer_kg_ha                  0
# Pesticide_Litre_ha                0
# Seed_Quality_Score                0
# Yield_Tonnes_Ha                  32
# Production_Tonnes                 0
# Market_Price_INR_Tonne            0
# Total_Cost_INR                    0
# Revenue_INR                       0
# ...

# %%
# Key Questions Addressed:
# - How does agricultural performance vary across seasons?
# - What major seasonal patterns can be observed?
print("--- 3. SEASONAL PERFORMANCE & VARIATIONS ---")

seasonal_performance = df.groupby('Season').agg({
    'Yield_Tonnes_Ha': ['mean', 'median', 'std'],
    'Production_Tonnes': ['mean', 'sum'],
    'Profit_INR': ['mean', 'median']
}).reset_index()

display(seasonal_performance)

# Visualization: Yield and Profit Variations Across Seasons
fig, axes = plt.subplots(1, 2, figsize=(14, 5))
sns.barplot(data=df, x='Season', y='Yield_Tonnes_Ha', ax=axes[0], palette='viridis', errorbar=None)
axes[0].set_title('Average Yield by Season (Tonnes/Ha)')
axes[0].set_ylabel('Yield (Tonnes/Ha)')

sns.barplot(data=df, x='Season', y='Profit_INR', ax=axes[1], palette='magma', errorbar=None)
axes[1].set_title('Average Profit by Season (INR)')
axes[1].set_ylabel('Profit (INR)')
plt.tight_layout()
plt.show()
# Out:
# --- 3. SEASONAL PERFORMANCE & VARIATIONS ---
#    Season Yield_Tonnes_Ha                   Production_Tonnes            \
#                      mean median        std              mean       sum
# 0  Kharif        5.630616   1.95  14.392286         46.311192  82387.61
# 1    Rabi        5.094917   1.66  12.829202         41.486712  67498.88
# 2    Zaid        4.637340   1.45  11.274305         38.886111  23098.35
#
#       Profit_INR
#             mean   median
# 0  178914.647555  38808.0
# 1   87689.470191  -3187.0
# 2  -24804.824916 -62144.0
# /tmp/ipykernel_524/4091835639.py:16: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=df, x='Season', y='Yield_Tonnes_Ha', ax=axes[0], palette='viridis', errorbar=None)
# /tmp/ipykernel_524/4091835639.py:20: FutureWarning:
#
# ...

# %%
# Key Questions Addressed:
# - Which characteristics change between seasons?
# - Are there noticeable variations in resource usage across seasons?
# - Are there relationships between seasonal environmental conditions and agricultural performance?
print("--- 4. ENVIRONMENTAL & RESOURCE USAGE ANALYSIS ---")

resource_env_summary = df.groupby('Season').agg({
    'Rainfall_mm': 'mean',
    'Avg_Temperature_C': 'mean',
    'Humidity_pct': 'mean',
    'Soil_Moisture_pct': 'mean',
    'Water_Used_m3': 'mean',
    'Water_Efficiency_t_per_1000m3': 'mean',
    'Fertilizer_kg_ha': 'mean',
    'Pesticide_Litre_ha': 'mean'
}).reset_index()

display(resource_env_summary)

# Visualization: Environmental Conditions Across Seasons
fig, axes = plt.subplots(1, 2, figsize=(14, 5))
sns.boxplot(data=df, x='Season', y='Rainfall_mm', ax=axes[0], palette='Set2')
axes[0].set_title('Rainfall Distribution (mm) Across Seasons')

sns.boxplot(data=df, x='Season', y='Avg_Temperature_C', ax=axes[1], palette='Set2')
axes[1].set_title('Average Temperature (°C) Across Seasons')
plt.tight_layout()
plt.show()
# Out:
# --- 4. ENVIRONMENTAL & RESOURCE USAGE ANALYSIS ---
#    Season  Rainfall_mm  Avg_Temperature_C  Humidity_pct  Soil_Moisture_pct  \
# 0  Kharif   852.108516          28.454019     71.812591          31.199044
# 1    Rabi   435.930670          23.489183     57.893178          24.049600
# 2    Zaid   299.336111          31.042088     52.012121          19.168519
#
#    Water_Used_m3  Water_Efficiency_t_per_1000m3  Fertilizer_kg_ha  \
# 0    6102.201237                       5.891834        187.077965
# 1    5846.987093                       5.186122        185.407068
# 2    6419.893939                       4.413239        184.638047
#
#    Pesticide_Litre_ha
# 0            5.079747
# 1            5.024690
# 2            5.171212
# /tmp/ipykernel_524/3195016574.py:22: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
# ...

# %%
# Key Questions Addressed:
# - How do economic outcomes vary across seasons?
# - Are some seasonal patterns consistent across different regions or categories?
print("--- 5. ECONOMIC OUTCOMES & REGIONAL CONSISTENCY ---")

economic_summary = df.groupby('Season').agg({
    'Total_Cost_INR': 'mean',
    'Revenue_INR': 'mean',
    'Profit_INR': 'mean'
}).reset_index()
display(economic_summary)

regional_profit = df.groupby(['State', 'Season'])['Profit_INR'].mean().unstack()
print("\nAverage Profit (INR) Across States and Seasons (Regional Consistency):")
display(regional_profit)

# Visualization: Regional Profit Consistency
plt.figure(figsize=(12, 6))
sns.barplot(data=df, x='State', y='Profit_INR', hue='Season', palette='coolwarm', errorbar=None)
plt.title('Regional Profitability Consistency Across States & Seasons')
plt.xticks(rotation=30)
plt.ylabel('Average Profit (INR)')
plt.legend(title='Season')
plt.show()
# Out:
# --- 5. ECONOMIC OUTCOMES & REGIONAL CONSISTENCY ---
#    Season  Total_Cost_INR    Revenue_INR     Profit_INR
# 0  Kharif   531804.408094  710719.055649  178914.647555
# 1    Rabi   513836.578365  601526.048556   87689.470191
# 2    Zaid   543976.728956  519171.904040  -24804.824916
# Average Profit (INR) Across States and Seasons (Regional Consistency):
# Season                 Kharif           Rabi           Zaid
# State
# Andhra Pradesh  169315.520833   26315.710784  -84084.870588
# Gujarat         217051.330317   82846.195000 -106929.611940
# Karnataka       201226.205742   70952.611650   23310.905405
# Madhya Pradesh  134242.398230   61576.264423     209.698413
# Maharashtra     168801.049550  159581.504587  -40597.597222
# Punjab          133779.099548  169294.521505   62109.688312
# Tamil Nadu      211303.956311   70456.860577  -15175.197183
# Telangana       199668.380342   62824.604061  -34620.776471

# %%
# Key Questions Addressed:
# - Are there unusual or unexpected seasonal patterns?
# - What differences exist between agricultural activities in different seasons?
print("--- 6. STATISTICAL CORRELATIONS & UNUSUAL PATTERNS ---")

numeric_cols = ['Rainfall_mm', 'Avg_Temperature_C', 'Humidity_pct', 'Soil_Moisture_pct',
                'Fertilizer_kg_ha', 'Seed_Quality_Score', 'Yield_Tonnes_Ha', 'Profit_INR', 'Disease_Pest_Risk_pct']

plt.figure(figsize=(10, 8))
correlation_matrix = df[numeric_cols].corr()
sns.heatmap(correlation_matrix, annot=True, cmap='Blues', fmt='.2f', linewidths=0.5)
plt.title('Correlation Matrix: Environmental & Agricultural Outcomes')
plt.show()

print("\nUnusual Pattern Check - Zaid Season Economic Strains:")
print(df.groupby('Season')[['Profit_INR', 'Water_Used_m3']].mean())
# Out:
# --- 6. STATISTICAL CORRELATIONS & UNUSUAL PATTERNS ---
# Unusual Pattern Check - Zaid Season Economic Strains:
#            Profit_INR  Water_Used_m3
# Season
# Kharif  178914.647555    6102.201237
# Rabi     87689.470191    5846.987093
# Zaid    -24804.824916    6419.893939

# %%
# Objective: Develop meaningful conclusions and data-driven recommendations for seasonal planning
print("--- 7. CONCLUSIONS & STRATEGIC RECOMMENDATIONS ---")
print("1. Seasonal Variations & Performance: Kharif yields the highest productivity and profitability (~₹1.79L avg profit) due to optimal monsoon rainfall (~852 mm), whereas Zaid incurs negative margins (-~₹24.8K) due to extreme heat (~31°C) and heavy irrigation overheads.")
print("2. Resource & Environmental Dynamics: Water consumption peaks during the dry Zaid season (~6,420 m³) despite minimal natural rainfall, showing high resource strain.")
print("3. Regional Patterns: Financial performance varies significantly by state; Punjab maintains resilience in Rabi/Zaid, while southern states experience steep profitability drops during dry cycles.")
print("4. Planning Support & Recommendations: Agricultural planning must mandate micro-irrigation (drip systems) and incentivize drought-resistant crop varieties during Zaid to convert negative losses into sustainable economic output.")
# Out:
# --- 7. CONCLUSIONS & STRATEGIC RECOMMENDATIONS ---
# 1. Seasonal Variations & Performance: Kharif yields the highest productivity and profitability (~₹1.79L avg profit) due to optimal monsoon rainfall (~852 mm), whereas Zaid incurs negative margins (-~₹24.8K) due to extreme heat (~31°C) and heavy irrigation overheads.
# 2. Resource & Environmental Dynamics: Water consumption peaks during the dry Zaid season (~6,420 m³) despite minimal natural rainfall, showing high resource strain.
# 3. Regional Patterns: Financial performance varies significantly by state; Punjab maintains resilience in Rabi/Zaid, while southern states experience steep profitability drops during dry cycles.
# 4. Planning Support & Recommendations: Agricultural planning must mandate micro-irrigation (drip systems) and incentivize drought-resistant crop varieties during Zaid to convert negative losses into sustainable economic output.
